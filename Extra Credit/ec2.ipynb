# %% [markdown]
# <a href="https://colab.research.google.com/github/ezahner/IDS/blob/main/Extra%20Credit/ec2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2023-09-06 at 5.02.55 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-06 at 5.04.03 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-09-06 at 5.04.29 PM.png](data:image/png;base64,...)

# %% [markdown]
# Here are some screenshots of me adding and manipulating the employee table in SQL. I did a list of empIDs and empNames, average of saleries, and sum of salarie.
