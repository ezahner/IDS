# %% [markdown]
# <a href="https://colab.research.google.com/github/ezahner/IDS/blob/main/HW2/Project2_Problem2_Excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 2 - Excel

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I imported the child mortality data into excel and filled in all missing values using the average of each column. The highlighted cells are the null values I replaced with averages.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After imputing all necessary values to fill in missing cells, I created graphs of the data. The first graph shows the mortality rates of children under five and of neonatal. This shows how much of the under five mortality rates are due to neonatal deaths. Next, I graphed infant mortality rates with neonatal mortality rates. This graph shows that the mortality rates of infants is much higher than that of neonatal. Finally, I graphed just the infant mortality rates according to the years associated with them. This shows that gernerally, the mortality rate decreased over time, however, there is some misleading data due to the fact that I had to input the mean for missing values. Looking over the graph as a whole, it seems as though there has been substantial progress of reducing child mortality rates over the past few decades.
